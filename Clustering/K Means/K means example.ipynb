# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

# %%
import sys
sys.path.append('../common')
from commonfunctions import visualize_dendrogram, visualize_cluster_data, run_visualization_example

# %%
# Read the dataset
dataset = pd.read_csv('../Data/data.csv')
dataset.head(10)
# Out:
#     x   y
# 0  11   7
# 1  12   7
# 2  18   9
# 3  10  10
# 4   8  11
# 5  11  10
# 6  11  10
# 7   5   6
# 8   8  10
# 9  20  15

# %%
# Visualize the data
X = dataset.iloc[:,[0,1]].values
clusters = [0] * X.shape[0]
visualize_cluster_data(plt, X, clusters,'Raw Data', [], 'ExampleRawData')

# %% [markdown]
# Set parameters for cluster values and centriods that we want to loop over the data.

# %%
centroids_list = [ 
    [(15,5), (5,15)],  
    [(15,5), (15,20)],
    [(20,8), (25,5)],
    [(15,5), (5,8), (20,15)],
    [(5,5), (5,8), (20,15)]
]

cluster_list = [2,2,2,3,3]

filenames = ["2cluster1","2cluster2","2cluster3","3cluster1","3cluster2"]

# %%
for example in range(5):
    run_visualization_example (plt, cluster_list[example], X, centroids_list[example], filenames[example])
